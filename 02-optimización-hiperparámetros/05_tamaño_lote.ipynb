# %% [markdown]
# # Optimización de hiperparámetros: tamaño de lote.
#
#
# @Tesis: Modelo de segmentación semántica de columnas de humo derivadas de incendios forestales en México
#
# @Autor: Colvert Gomez Rubio

# %% [markdown]
# ### Librerías

# %%
import matplotlib.pyplot as plt
import os
import torch
from torch import nn
from torch.nn import functional
from torchvision import transforms
from torch.utils.data import DataLoader, Dataset, random_split
from PIL import Image
import pandas as pd
import time
from torch.cuda import amp

# %% [markdown]
# ### GPU ó CPU

# %%
# Verificar si CUDA está disponible y seleccionar el dispositivo correspondiente
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print(device)

# Inicializar el escalador de gradientes
scaler = amp.GradScaler()
# Out:
# cuda

# %% [markdown]
# ### Directorios

# %%
 # Definimos la ruta base para nuestro dataset
base_path = os.path.join(os.path.dirname(os.getcwd()) , 'GOES16-wildfires-smoke-plumes-dataset\GOES16-wildfires-smoke-plumes-dataset')

 # Definimos las rutas para los conjuntos de entrenamiento y sus máscaras
train_path = os.path.join(base_path, 'train')
train_masks_path = os.path.join(base_path, 'train_masks')

 # Definimos las rutas para los conjuntos de validación y sus máscaras
valid_path = os.path.join(base_path, 'valid')
valid_masks_path = os.path.join(base_path, 'valid_masks')

 # Definimos las rutas para los conjuntos de prueba y sus máscaras
test_path = os.path.join(base_path, 'test')
test_masks_path = os.path.join(base_path, 'test_masks')

# %% [markdown]
# ### Dataset

# %%
class SmokeDataset(Dataset):
    """
    Clase para representar un conjunto de datos de imágenes y máscaras de humo.

    Parámetros:
        images (str): Ruta al directorio que contiene las imágenes.
        masks (str, opcional): Ruta al directorio que contiene las máscaras. Default es None.
        img_transforms (callable, opcional): Transformaciones a aplicar a las imágenes. Default es None.
        mask_transforms (callable, opcional): Transformaciones a aplicar a las máscaras. Default es None.

    Atributos:
        images (str): Ruta al directorio que contiene las imágenes.
        masks (str, opcional): Ruta al directorio que contiene las máscaras.
        img_transforms (callable, opcional): Transformaciones a aplicar a las imágenes.
        mask_transforms (callable, opcional): Transformaciones a aplicar a las máscaras.
        image_files (list): Lista ordenada de nombres de archivo de las imágenes en el directorio.
        mask_files (list): Lista ordenada de nombres de archivo de las máscaras en el directorio.

    Excepciones:
        AssertionError: Si se proporcionan máscaras, pero el número de imágenes y máscaras no coincide.

    Metodos:
        __len__(): Retorna el número de imágenes en el conjunto de datos.
        __getitem__(idx): Retorna la imagen y su máscara asociada en la posición 'idx'.

    Ejemplo:
        dataset = SmokeDataset(images='/ruta/a/imagenes', masks='/ruta/a/mascaras',
                              img_transforms=transforms.Compose([transforms.Resize((256, 256)),
                                                                transforms.ToTensor()]),
                              mask_transforms=transforms.Compose([transforms.Resize((256, 256)),
                                                                 transforms.ToTensor()]))
        image, mask = dataset[0]

    """

    def __init__(self, images, masks = None, img_transforms = None, mask_transforms = None):
        """
        Constructor de la clase SmokeDataset.

        Parámetros:
            images (str): Ruta al directorio que contiene las imágenes.
            masks (str, opcional): Ruta al directorio que contiene las máscaras. Default es None.
            img_transforms (callable, opcional): Transformaciones a aplicar a las imágenes. Default es None.
            mask_transforms (callable, opcional): Transformaciones a aplicar a las máscaras. Default es None.

        """
        self.images = images
        self.masks = masks

        self.img_transforms = img_transforms
        self.mask_transforms = mask_transforms

        # Inicializar listas de archivos de imágenes y máscaras
        self.image_files = []
        self.mask_files = []

        # Si se proporcionan máscaras, asegurar que el número de imágenes y máscaras coincida
        if self.masks is not None:
            assert len(os.listdir(self.images)) == len(os.listdir(self.masks)), 'no hay el mismo número de imágenes y máscaras'
            # Obtener lista de archivos de imágenes y máscaras ordenados
            self.image_files = sorted(os.listdir(self.images))
            self.mask_files = sorted(os.listdir(self.masks))
        else:
            # Obtener lista de archivos de imágenes ordenados
            self.image_files = sorted(os.listdir(self.images))

    def __len__(self):
        """
        Método para obtener la cantidad de imágenes en el conjunto de datos.

        Retorna:
            int: Número de imágenes en el conjunto de datos.

        """
        return len(self.image_files)

    def __getitem__(self, idx):
        """
        Método para obtener la imagen y su máscara asociada en la posición 'idx'.

        Parámetros:
            idx (int): Índice de la imagen a obtener.

        Retorna:
            tuple: Tupla con la imagen y su máscara asociada, si las máscaras están disponibles.
                   Si no hay máscaras, retorna solo la imagen.

        """

        image_name = os.path.join(self.images, self.image_files[idx])
        img = Image.open(image_name)
        # Transformar la imagen a tensor
        trans = transforms.ToTensor()

        # Aplicar transformaciones a la imagen si se proporcionan
        if self.img_transforms is not None:
            img = self.img_transforms(img)
        else:
            img = trans(img)

        # Si se proporcionan máscaras, obtener y transformar la máscara asociada a la imagen
        if self.masks is not None:
            mask_name = os.path.join(self.masks, self.mask_files[idx])
            mask = Image.open(mask_name)
            # Aplicar transformaciones a la máscara si se proporcionan
            if self.mask_transforms is not None:
                mask = self.mask_transforms(mask)
            else:
                mask = trans(mask)
            # Normalizar la máscara
            mask_max = mask.max().item()
            mask /= mask_max
            return img, mask
        else:
            return img

# %%
#Definir la transformación de datos
transform_data = transforms.Compose([
    transforms.Resize([128, 128]),
    transforms.ToTensor()])

# Crear el conjunto de datos de entrenamiento
train_dataset = SmokeDataset(train_path, train_masks_path,
                             img_transforms = transform_data,
                             mask_transforms = transform_data)

# Crear el conjunto de datos de validación
val_dataset = SmokeDataset(valid_path, valid_masks_path,
                           img_transforms = transform_data, mask_transforms = transform_data)

# Crear el conjunto de datos de prueba
test_dataset = SmokeDataset(test_path, test_masks_path, 
                            img_transforms = transform_data, mask_transforms = transform_data)

print(f'Número de imágenes de entrenamiento: {len(train_dataset)}, validación: {len(val_dataset)}, prueba:{len(test_dataset)}')
# Out:
# Número de imágenes de entrenamiento: 731, validación: 207, prueba:123

# %% [markdown]
# ### Métricas

# %%
def metrics(model, loader):
    """
    Calcula la precisión y otras métricas de evaluación para un modelo dado utilizando un DataLoader.

    Parámetros:
        model (torch.nn.Module): El modelo a evaluar.
        loader (torch.utils.data.DataLoader): DataLoader que contiene los datos de evaluación.

    Retorna:
        tuple: Una tupla que contiene las siguientes métricas de evaluación:
            - val_cost (float): Costo promedio de la función de pérdida (cross_entropy).
            - val_acc (float): Precisión (accuracy) promedio del modelo.
            - dice (float): Coeficiente Dice, una medida de similitud entre las predicciones y las etiquetas reales.
            - iou (float): Índice de Jaccard (IoU), otra medida de similitud para problemas de segmentación.
            - tp (int): True Positives.
            - tn (int): True Negatives.
            - fp (int): False Positives.
            - fn (int): False Negatives.
    """
    cost = 0.0
    tp = 0
    tn = 0
    fp = 0
    fn = 0
    model = model.to(device=device)
    # Desactiva el cálculo del gradiente durante la ejecución de este bloque de código
    with torch.no_grad():
        # Itera sobre los datos del cargador
        for x, y in loader:
            x = x.to(device=device, dtype=torch.float32)
            y = y.to(device=device, dtype=torch.long).squeeze(1)
            with amp.autocast():
                # Calcula las puntuaciones del modelo
                scores = model(x)
                # Calcula el costo utilizando la función de pérdida de entropía cruzada
                cost += functional.cross_entropy(scores, y).item()
                # Calcula las predicciones del modelo
                preds = torch.max(scores, dim=1)[1]

                # Calcula TP, TN, FP, FN
                tp += ((preds == 1) & (y == 1)).sum().item()
                tn += ((preds == 0) & (y == 0)).sum().item()
                fp += ((preds == 1) & (y == 0)).sum().item()
                fn += ((preds == 0) & (y == 1)).sum().item()

    # Calcular las métricas finales
    dice = (2 * tp) / (2 * tp + fp + fn + 1e-8)
    iou = (tp) / (tp + fp + fn + 1e-8)
    acc = (tp + tn) / (tp + tn + fp + fn + 1e-8)
    val_cost = cost / len(loader)
    
    return val_cost, acc, dice, iou, tp, tn, fp, fn

# %% [markdown]
# # Función de entrenamiento

# %%
def train(model, optimiser, scheduler = None, epochs = 5, store_every = 1):
    """
    Entrena el modelo utilizando el optimizador especificado durante varias épocas.

    Parámetros:
        model (torch.nn.Module): El modelo a entrenar.
        optimiser (torch.optim.Optimizer): El optimizador utilizado para actualizar los pesos del modelo.
        scheduler (torch.optim.lr_scheduler._LRScheduler, opcional): El programador de tasas de aprendizaje (LR scheduler).
            Por defecto, es None, lo que significa que no se utiliza un programador de tasas de aprendizaje.
        epochs (int, opcional): El número de épocas (iteraciones completas) para entrenar el modelo. Por defecto es 5.
        store_every (int, opcional): Intervalo de épocas para almacenar las métricas. Por defecto es 1.

    Retorna:
        None: La función no devuelve nada, pero entrena el modelo y almacena las métricas en listas globales.
              (train_acc_history, val_acc_history, train_cost_history, val_cost_history, dice_history, iou_history)
    """
    start_time = time.time()  # Obtener el tiempo de inicio del entrenamiento

    # Crear DataFrame vacío
    history_df = pd.DataFrame()

    model = model.to(device=device)

    for epoch in range(epochs):
        train_correct_num = 0
        train_total = 0
        train_cost_acum = 0.

        for mb, (x, y) in enumerate(train_loader, start=1):
            model.train()
            x = x.to(device=device, dtype=torch.float32)
            y = y.to(device=device, dtype=torch.long).squeeze(1)

            optimiser.zero_grad()

            with amp.autocast():
                #Calcula las puntuaciones y el coste
                scores = model(x)
                cost = functional.cross_entropy(input=scores, target=y)

            #Realiza un paso de optimización
            # cost.backward()
            scaler.scale(cost).backward()
            # optimiser.step()
            scaler.step(optimiser)
            scaler.update()

            # Si se proporciona un programador, se aplica a cada paso de optimización
            if scheduler:
                scheduler.step()

            #Calcula las métricas de entrenamiento
            with torch.no_grad():
                train_predictions = torch.argmax(scores, dim=1)
                train_correct_num += (train_predictions == y).sum()
                train_total += torch.numel(train_predictions)
                train_cost_acum += cost

        # Calcula e imprime las métricas al final de cada época
        if epoch%store_every == 0:
            model.eval()
            train_cost2, train_acc2, train_dice, train_iou, tp, tn, fp, fn = metrics(model,train_loader)
            val_cost, val_acc, val_dice, val_iou, tp, tn, fp, fn = metrics(model, val_loader)

            train_acc = float(train_correct_num) / train_total
            train_cost_every = float(train_cost_acum) / len(train_loader)

            print(f'epoch: {epoch + 1}, train cost: {train_cost_every:.4f}, val cost: {val_cost:.4f},'
                  f' train acc: {train_acc:.4f}, val acc: {val_acc:.4f},'
                  f' dice train: {train_dice:.4f}, dice val: {val_dice:.4f},'
                  f' iou train: {train_iou:.4f}, iou val: {val_iou:.4f}')

            # Almacena las métricas en el DataFrame
            history_df.loc[epoch, 'epoch'] = epoch + 1

            history_df.loc[epoch, 'train_acc'] = train_acc
            history_df.loc[epoch, 'val_acc'] = val_acc

            history_df.loc[epoch, 'train_cost'] = train_cost_every
            history_df.loc[epoch, 'val_cost'] = val_cost

            history_df.loc[epoch, 'train_dice'] = train_dice
            history_df.loc[epoch, 'val_dice'] = val_dice

            history_df.loc[epoch, 'train_iou'] = train_iou
            history_df.loc[epoch, 'val_iou'] = val_iou


    end_time = time.time()  # Obtener el tiempo de finalización del entrenamiento
    total_time = end_time - start_time  # Calcular el tiempo total de ejecución
    # Convertir el tiempo total a formato horas:minutos:segundos
    total_time_str = time.strftime("%H:%M:%S", time.gmtime(total_time))
    # Imprimir el tiempo total de ejecución en formato horas:minutos:segundos
    print("Tiempo total de ejecución:", total_time_str)

    return history_df

# %% [markdown]
# ### Modelo UNet

# %%
class Conv3k(nn.Module):
    def __init__(self, channels_in, channels_out):
        """
        Inicializa una capa de convolución 2D con kernel de tamaño 3x3, stride de 1 y padding de 1.

        Parámetros:
            channels_in (int): Número de canales de entrada.
            channels_out (int): Número de canales de salida.
        """
        super().__init__()
        #Capa de convolución
        self.conv1 = nn.Conv2d(channels_in, channels_out, kernel_size = 3, stride = 1, padding = 1)

    def forward(self, x):
        """
        Realiza una operación de convolución 2D con la entrada dada.

        Parámetros:
            x (torch.Tensor): Tensor de entrada.

        Retorna:
            torch.Tensor: Tensor resultante después de la convolución.
        """
        return self.conv1(x)


class DoubleConv(nn.Module):
    def __init__(self, channels_in, channels_out):
        """
        Inicializa un bloque de doble convolución seguido de normalización y función de activación LeakyReLU.

        Parámetros:
            channels_in (int): Número de canales de entrada.
            channels_out (int): Número de canales de salida.
        """
        super().__init__()
        self.double_conv = nn.Sequential(
                           Conv3k(channels_in, channels_out),
                           nn.BatchNorm2d(channels_out),
                           nn.LeakyReLU(),

                           Conv3k(channels_out, channels_out),
                           nn.BatchNorm2d(channels_out),
                           nn.LeakyReLU()
                            )

    def forward(self, x):
        """
        Realiza una operación de doble convolución seguida de normalización y LeakyReLU.

        Parámetros:
            x (torch.Tensor): Tensor de entrada.

        Retorna:
            torch.Tensor: Tensor resultante después de la doble convolución.
        """
        return self.double_conv(x)


class DownConv(nn.Module):
    def __init__(self, channels_in, channels_out):
        """
        Inicializa un bloque de convolución descendente que incluye una capa de MaxPool2D y una DoubleConv.

        Parámetros:
            channels_in (int): Número de canales de entrada.
            channels_out (int): Número de canales de salida.
        """
        super().__init__()
        self.encoder = nn.Sequential(
                        nn.MaxPool2d(2, 2),
                        DoubleConv(channels_in, channels_out)
                        )

    def forward(self, x):
        """
        Realiza una operación de convolución descendente con la entrada dada.

        Parámetros:
            x (torch.Tensor): Tensor de entrada.

        Retorna:
            torch.Tensor: Tensor resultante después de la convolución descendente.
        """
        return self.encoder(x)


class UpConv(nn.Module):
    def __init__(self, channels_in, channels_out):
        """
        Inicializa un bloque de convolución ascendente que incluye una capa de Upsample, una capa de convolución y una DoubleConv.

        Parámetros:
            channels_in (int): Número de canales de entrada.
            channels_out (int): Número de canales de salida.
        """
        super().__init__()
        self.upsample_layer = nn.Sequential(
                        nn.Upsample(scale_factor=2, mode='bicubic'),
                        nn.Conv2d(channels_in, channels_in // 2, kernel_size = 1, stride = 1)
                        )
        self.decoder = DoubleConv(channels_in, channels_out)

    def forward(self, x1, x2):
        """
        Realiza una operación de convolución ascendente con las entradas dadas.

        Parámetros:
            x1 (torch.Tensor): Tensor de entrada upsampled.
            x2 (torch.Tensor): Tensor de entrada para la concatenación.

        Retorna:
            torch.Tensor: Tensor resultante después de la convolución ascendente.
        """
        x1 = self.upsample_layer(x1)
        x = torch.cat([x2, x1], dim=1)
        return self.decoder(x)


class Unet(nn.Module):
    def __init__(self, channels_in, channels, num_classes):
        """
        Inicializa una arquitectura U-Net que consiste en bloques de convolución descendente y ascendente.

        Parámetros:
            channels_in (int): Número de canales de entrada.
            channels (int): Número de canales para las capas intermedias.
            num_classes (int): Número de clases de salida.
        """
        super().__init__()
        self.first_conv = DoubleConv(channels_in, channels)
        self.down_conv1 = DownConv(channels, 2 * channels)
        self.down_conv2 = DownConv(2 * channels, 4 * channels)
        self.down_conv3 = DownConv(4 * channels, 8 * channels)

        self.middle_conv = DownConv(8 * channels, 16 * channels)

        self.up_conv1 = UpConv(16 * channels, 8 * channels)
        self.up_conv2 = UpConv(8 * channels, 4 * channels)
        self.up_conv3 = UpConv(4 * channels, 2 * channels)
        self.up_conv4 = UpConv(2 * channels, channels)

        self.last_conv = nn.Conv2d(channels, num_classes, kernel_size = 1, stride = 1)

    def forward(self, x):
        """
        Realiza una pasada hacia adelante a través de la arquitectura U-Net.

        Parámetros:
            x (torch.Tensor): Tensor de entrada.

        Retorna:
            torch.Tensor: Tensor resultante después de pasar por la U-Net.
        """
        x1 = self.first_conv(x)
        x2 = self.down_conv1(x1)
        x3 = self.down_conv2(x2)
        x4 = self.down_conv3(x3)

        x5 = self.middle_conv(x4)

        u1 = self.up_conv1(x5, x4)
        u2 = self.up_conv2(u1, x3)
        u3 = self.up_conv3(u2, x2)
        u4 = self.up_conv4(u3, x1)

        return self.last_conv(u4)

# %% [markdown]
# ### Definición del modelo y entrenamiento

# %%
batch_sizes = [4, 8, 16, 32]
results = []

for batch_size in batch_sizes:
    # DataLoader de entrenamiento, validación y prueba
    train_loader = DataLoader(train_dataset, batch_size = batch_size, shuffle = True)
    val_loader = DataLoader(val_dataset, batch_size = batch_size, shuffle = True)
    test_loader = DataLoader(test_dataset, batch_size = len(test_dataset), shuffle = False)

    print(f'batch size: {batch_size}')
    print(f'Número de mini-batches de train: {len(train_loader)}, val: {len(val_loader)}, test:{len(test_loader)}')

    torch.manual_seed(42)
    model = Unet(3, 32, 2)
    epochs = 20
    optimiser_unet = torch.optim.SGD(model.parameters(),
                                    lr = 0.01, momentum = 0.95,
                                    weight_decay = 1e-4)


    history_df = train(model, optimiser_unet, scheduler = None, epochs = epochs)

    # Guardar los resultados en un diccionario
    result = {"Batch_size": str(batch_size), "History": history_df}
    results.append(result)
# Out:
# batch size: 4
# Número de mini-batches de train: 183, val: 52, test:1
# epoch: 1, train cost: 0.1210, val cost: 0.0768, train acc: 0.9518, val acc: 0.9722, dice train: 0.6991, dice val: 0.6909, iou train: 0.5374, iou val: 0.5278
# epoch: 2, train cost: 0.0568, val cost: 0.0440, train acc: 0.9776, val acc: 0.9817, dice train: 0.8306, dice val: 0.8357, iou train: 0.7103, iou val: 0.7178
# epoch: 3, train cost: 0.0455, val cost: 0.0435, train acc: 0.9817, val acc: 0.9830, dice train: 0.8156, dice val: 0.8233, iou train: 0.6886, iou val: 0.6997
# epoch: 4, train cost: 0.0384, val cost: 0.0353, train acc: 0.9842, val acc: 0.9851, dice train: 0.8577, dice val: 0.8610, iou train: 0.7509, iou val: 0.7559
# epoch: 5, train cost: 0.0373, val cost: 0.0342, train acc: 0.9847, val acc: 0.9859, dice train: 0.8629, dice val: 0.8652, iou train: 0.7588, iou val: 0.7624
# epoch: 6, train cost: 0.0411, val cost: 0.0461, train acc: 0.9830, val acc: 0.9832, dice train: 0.8285, dice val: 0.8295, iou train: 0.7072, iou val: 0.7087
# epoch: 7, train cost: 0.0370, val cost: 0.0380, train acc: 0.9847, val acc: 0.9851, dice train: 0.8535, dice val: 0.8482, iou train: 0.7445, iou val: 0.7363
# epoch: 8, train cost: 0.0327, val cost: 0.0340, train acc: 0.9864, val acc: 0.9858, dice train: 0.8705, dice val: 0.8677, iou train: 0.7707, iou val: 0.7663
# epoch: 9, train cost: 0.0306, val cost: 0.0315, train acc: 0.9872, val acc: 0.9872, dice train: 0.8786, dice val: 0.8778, iou train: 0.7835, iou val: 0.7822
# epoch: 10, train cost: 0.0290, val cost: 0.0323, train acc: 0.9879, val acc: 0.9869, dice train: 0.8759, dice val: 0.8694, iou train: 0.7792, iou val: 0.7689
# epoch: 11, train cost: 0.0284, val cost: 0.0319, train acc: 0.9881, val acc: 0.9869, dice train: 0.8829, dice val: 0.8770, iou train: 0.7903, iou val: 0.7810
# epoch: 12, train cost: 0.0271, val cost: 0.0279, train acc: 0.9886, val acc: 0.9884, dice train: 0.8951, dice val: 0.8879, iou train: 0.8101, iou val: 0.7984
# epoch: 13, train cost: 0.0266, val cost: 0.0283, train acc: 0.9888, val acc: 0.9883, dice train: 0.8991, dice val: 0.8915, iou train: 0.8168, iou val: 0.8042
# epoch: 14, train cost: 0.0253, val cost: 0.0272, train acc: 0.9893, val acc: 0.9887, dice train: 0.9007, dice val: 0.8904, iou train: 0.8194, iou val: 0.8024
# epoch: 15, train cost: 0.0250, val cost: 0.0278, train acc: 0.9894, val acc: 0.9882, dice train: 0.8965, dice val: 0.8885, iou train: 0.8124, iou val: 0.7994
# epoch: 16, train cost: 0.0238, val cost: 0.0288, train acc: 0.9899, val acc: 0.9880, dice train: 0.8991, dice val: 0.8903, iou train: 0.8167, iou val: 0.8024
# epoch: 17, train cost: 0.0238, val cost: 0.0269, train acc: 0.9899, val acc: 0.9888, dice train: 0.9082, dice val: 0.8958, iou train: 0.8318, iou val: 0.8112
# epoch: 18, train cost: 0.0235, val cost: 0.0262, train acc: 0.9900, val acc: 0.9893, dice train: 0.9096, dice val: 0.8983, iou train: 0.8342, iou val: 0.8154
# epoch: 19, train cost: 0.0230, val cost: 0.0259, train acc: 0.9902, val acc: 0.9892, dice train: 0.9120, dice val: 0.8972, iou train: 0.8383, iou val: 0.8136
# epoch: 20, train cost: 0.0222, val cost: 0.0274, train acc: 0.9905, val acc: 0.9889, dice train: 0.9087, dice val: 0.8939, iou train: 0.8327, iou val: 0.8081
# Tiempo total de ejecución: 00:07:46
# batch size: 8
# Número de mini-batches de train: 92, val: 26, test:1
# epoch: 1, train cost: 0.1628, val cost: 0.0855, train acc: 0.9302, val acc: 0.9696, dice train: 0.6829, dice val: 0.6771, iou train: 0.5185, iou val: 0.5118
# epoch: 2, train cost: 0.0603, val cost: 0.0685, train acc: 0.9766, val acc: 0.9701, dice train: 0.7367, dice val: 0.7474, iou train: 0.5831, iou val: 0.5967
# epoch: 3, train cost: 0.0508, val cost: 0.0392, train acc: 0.9797, val acc: 0.9840, dice train: 0.8385, dice val: 0.8442, iou train: 0.7219, iou val: 0.7304
# epoch: 4, train cost: 0.0393, val cost: 0.0405, train acc: 0.9838, val acc: 0.9831, dice train: 0.8466, dice val: 0.8496, iou train: 0.7340, iou val: 0.7386
# epoch: 5, train cost: 0.0369, val cost: 0.0339, train acc: 0.9848, val acc: 0.9860, dice train: 0.8678, dice val: 0.8666, iou train: 0.7665, iou val: 0.7647
# epoch: 6, train cost: 0.0355, val cost: 0.0341, train acc: 0.9854, val acc: 0.9859, dice train: 0.8721, dice val: 0.8666, iou train: 0.7731, iou val: 0.7646
# epoch: 7, train cost: 0.0341, val cost: 0.0312, train acc: 0.9859, val acc: 0.9871, dice train: 0.8779, dice val: 0.8737, iou train: 0.7824, iou val: 0.7757
# epoch: 8, train cost: 0.0313, val cost: 0.0313, train acc: 0.9869, val acc: 0.9868, dice train: 0.8853, dice val: 0.8787, iou train: 0.7942, iou val: 0.7837
# epoch: 9, train cost: 0.0297, val cost: 0.0339, train acc: 0.9876, val acc: 0.9859, dice train: 0.8703, dice val: 0.8672, iou train: 0.7704, iou val: 0.7655
# epoch: 10, train cost: 0.0295, val cost: 0.0377, train acc: 0.9878, val acc: 0.9855, dice train: 0.8558, dice val: 0.8499, iou train: 0.7480, iou val: 0.7389
# epoch: 11, train cost: 0.0285, val cost: 0.0297, train acc: 0.9882, val acc: 0.9878, dice train: 0.8906, dice val: 0.8835, iou train: 0.8027, iou val: 0.7912
# epoch: 12, train cost: 0.0270, val cost: 0.0303, train acc: 0.9888, val acc: 0.9873, dice train: 0.8918, dice val: 0.8827, iou train: 0.8048, iou val: 0.7900
# epoch: 13, train cost: 0.0257, val cost: 0.0271, train acc: 0.9891, val acc: 0.9887, dice train: 0.9036, dice val: 0.8941, iou train: 0.8242, iou val: 0.8085
# epoch: 14, train cost: 0.0252, val cost: 0.0277, train acc: 0.9894, val acc: 0.9886, dice train: 0.8996, dice val: 0.8879, iou train: 0.8175, iou val: 0.7984
# epoch: 15, train cost: 0.0250, val cost: 0.0260, train acc: 0.9896, val acc: 0.9891, dice train: 0.9082, dice val: 0.8972, iou train: 0.8319, iou val: 0.8135
# epoch: 16, train cost: 0.0239, val cost: 0.0271, train acc: 0.9900, val acc: 0.9887, dice train: 0.9078, dice val: 0.8939, iou train: 0.8312, iou val: 0.8082
# epoch: 17, train cost: 0.0234, val cost: 0.0265, train acc: 0.9901, val acc: 0.9891, dice train: 0.9092, dice val: 0.8949, iou train: 0.8334, iou val: 0.8097
# epoch: 18, train cost: 0.0227, val cost: 0.0263, train acc: 0.9904, val acc: 0.9892, dice train: 0.9137, dice val: 0.8991, iou train: 0.8411, iou val: 0.8168
# epoch: 19, train cost: 0.0233, val cost: 0.0269, train acc: 0.9902, val acc: 0.9890, dice train: 0.9146, dice val: 0.8966, iou train: 0.8426, iou val: 0.8126
# epoch: 20, train cost: 0.0223, val cost: 0.0274, train acc: 0.9906, val acc: 0.9890, dice train: 0.9094, dice val: 0.8950, iou train: 0.8338, iou val: 0.8099
# Tiempo total de ejecución: 00:07:31
# batch size: 16
# Número de mini-batches de train: 46, val: 13, test:1
# epoch: 1, train cost: 0.2183, val cost: 0.2095, train acc: 0.9095, val acc: 0.9476, dice train: 0.0000, dice val: 0.0000, iou train: 0.0000, iou val: 0.0000
# epoch: 2, train cost: 0.0765, val cost: 0.0743, train acc: 0.9674, val acc: 0.9757, dice train: 0.7287, dice val: 0.7439, iou train: 0.5732, iou val: 0.5923
# epoch: 3, train cost: 0.0541, val cost: 0.0455, train acc: 0.9784, val acc: 0.9823, dice train: 0.8335, dice val: 0.8357, iou train: 0.7145, iou val: 0.7177
# epoch: 4, train cost: 0.0412, val cost: 0.0365, train acc: 0.9830, val acc: 0.9852, dice train: 0.8520, dice val: 0.8585, iou train: 0.7422, iou val: 0.7520
# epoch: 5, train cost: 0.0371, val cost: 0.0404, train acc: 0.9847, val acc: 0.9829, dice train: 0.8454, dice val: 0.8475, iou train: 0.7322, iou val: 0.7354
# epoch: 6, train cost: 0.0361, val cost: 0.0410, train acc: 0.9850, val acc: 0.9837, dice train: 0.8265, dice val: 0.8302, iou train: 0.7043, iou val: 0.7097
# epoch: 7, train cost: 0.0349, val cost: 0.0404, train acc: 0.9854, val acc: 0.9842, dice train: 0.8376, dice val: 0.8393, iou train: 0.7206, iou val: 0.7230
# epoch: 8, train cost: 0.0323, val cost: 0.0311, train acc: 0.9865, val acc: 0.9870, dice train: 0.8787, dice val: 0.8748, iou train: 0.7836, iou val: 0.7775
# epoch: 9, train cost: 0.0310, val cost: 0.0311, train acc: 0.9871, val acc: 0.9870, dice train: 0.8826, dice val: 0.8774, iou train: 0.7899, iou val: 0.7817
# epoch: 10, train cost: 0.0293, val cost: 0.0300, train acc: 0.9878, val acc: 0.9878, dice train: 0.8903, dice val: 0.8834, iou train: 0.8023, iou val: 0.7911
# epoch: 11, train cost: 0.0277, val cost: 0.0291, train acc: 0.9885, val acc: 0.9880, dice train: 0.8922, dice val: 0.8838, iou train: 0.8053, iou val: 0.7918
# epoch: 12, train cost: 0.0272, val cost: 0.0280, train acc: 0.9887, val acc: 0.9883, dice train: 0.9014, dice val: 0.8903, iou train: 0.8204, iou val: 0.8023
# epoch: 13, train cost: 0.0259, val cost: 0.0273, train acc: 0.9891, val acc: 0.9888, dice train: 0.9041, dice val: 0.8918, iou train: 0.8250, iou val: 0.8047
# epoch: 14, train cost: 0.0261, val cost: 0.0292, train acc: 0.9891, val acc: 0.9882, dice train: 0.8946, dice val: 0.8846, iou train: 0.8093, iou val: 0.7931
# epoch: 15, train cost: 0.0257, val cost: 0.0279, train acc: 0.9893, val acc: 0.9884, dice train: 0.9054, dice val: 0.8911, iou train: 0.8271, iou val: 0.8036
# epoch: 16, train cost: 0.0243, val cost: 0.0271, train acc: 0.9899, val acc: 0.9889, dice train: 0.9117, dice val: 0.8942, iou train: 0.8378, iou val: 0.8086
# epoch: 17, train cost: 0.0243, val cost: 0.0284, train acc: 0.9898, val acc: 0.9885, dice train: 0.9002, dice val: 0.8878, iou train: 0.8185, iou val: 0.7983
# epoch: 18, train cost: 0.0234, val cost: 0.0270, train acc: 0.9902, val acc: 0.9890, dice train: 0.9123, dice val: 0.8957, iou train: 0.8387, iou val: 0.8112
# epoch: 19, train cost: 0.0229, val cost: 0.0275, train acc: 0.9904, val acc: 0.9889, dice train: 0.9149, dice val: 0.8965, iou train: 0.8432, iou val: 0.8124
# epoch: 20, train cost: 0.0220, val cost: 0.0268, train acc: 0.9908, val acc: 0.9891, dice train: 0.9172, dice val: 0.8978, iou train: 0.8470, iou val: 0.8145
# Tiempo total de ejecución: 00:07:27
# batch size: 32
# Número de mini-batches de train: 23, val: 7, test:1
# epoch: 1, train cost: 0.3403, val cost: 0.1925, train acc: 0.8482, val acc: 0.9476, dice train: 0.0000, dice val: 0.0000, iou train: 0.0000, iou val: 0.0000
# epoch: 2, train cost: 0.1215, val cost: 0.2163, train acc: 0.9487, val acc: 0.9476, dice train: 0.0000, dice val: 0.0000, iou train: 0.0000, iou val: 0.0000
# epoch: 3, train cost: 0.0817, val cost: 0.0801, train acc: 0.9621, val acc: 0.9702, dice train: 0.6518, dice val: 0.6506, iou train: 0.4834, iou val: 0.4821
# epoch: 4, train cost: 0.0520, val cost: 0.0465, train acc: 0.9793, val acc: 0.9818, dice train: 0.8165, dice val: 0.8208, iou train: 0.6900, iou val: 0.6960
# epoch: 5, train cost: 0.0448, val cost: 0.0517, train acc: 0.9817, val acc: 0.9797, dice train: 0.8212, dice val: 0.8198, iou train: 0.6966, iou val: 0.6946
# epoch: 6, train cost: 0.0397, val cost: 0.0405, train acc: 0.9838, val acc: 0.9840, dice train: 0.8386, dice val: 0.8388, iou train: 0.7221, iou val: 0.7224
# epoch: 7, train cost: 0.0364, val cost: 0.0356, train acc: 0.9848, val acc: 0.9854, dice train: 0.8634, dice val: 0.8609, iou train: 0.7596, iou val: 0.7558
# epoch: 8, train cost: 0.0335, val cost: 0.0333, train acc: 0.9862, val acc: 0.9864, dice train: 0.8739, dice val: 0.8677, iou train: 0.7761, iou val: 0.7662
# epoch: 9, train cost: 0.0323, val cost: 0.0307, train acc: 0.9867, val acc: 0.9871, dice train: 0.8835, dice val: 0.8792, iou train: 0.7914, iou val: 0.7845
# epoch: 10, train cost: 0.0302, val cost: 0.0333, train acc: 0.9874, val acc: 0.9866, dice train: 0.8790, dice val: 0.8670, iou train: 0.7841, iou val: 0.7652
# epoch: 11, train cost: 0.0295, val cost: 0.0299, train acc: 0.9877, val acc: 0.9872, dice train: 0.8871, dice val: 0.8796, iou train: 0.7971, iou val: 0.7851
# epoch: 12, train cost: 0.0273, val cost: 0.0292, train acc: 0.9886, val acc: 0.9879, dice train: 0.8965, dice val: 0.8857, iou train: 0.8125, iou val: 0.7948
# epoch: 13, train cost: 0.0265, val cost: 0.0286, train acc: 0.9889, val acc: 0.9882, dice train: 0.9023, dice val: 0.8889, iou train: 0.8219, iou val: 0.8000
# epoch: 14, train cost: 0.0261, val cost: 0.0285, train acc: 0.9891, val acc: 0.9881, dice train: 0.9031, dice val: 0.8895, iou train: 0.8234, iou val: 0.8009
# epoch: 15, train cost: 0.0249, val cost: 0.0272, train acc: 0.9897, val acc: 0.9886, dice train: 0.9074, dice val: 0.8922, iou train: 0.8305, iou val: 0.8055
# epoch: 16, train cost: 0.0244, val cost: 0.0288, train acc: 0.9898, val acc: 0.9881, dice train: 0.9068, dice val: 0.8908, iou train: 0.8296, iou val: 0.8031
# epoch: 17, train cost: 0.0239, val cost: 0.0274, train acc: 0.9901, val acc: 0.9889, dice train: 0.9106, dice val: 0.8938, iou train: 0.8359, iou val: 0.8080
# epoch: 18, train cost: 0.0232, val cost: 0.0270, train acc: 0.9903, val acc: 0.9890, dice train: 0.9135, dice val: 0.8964, iou train: 0.8407, iou val: 0.8123
# epoch: 19, train cost: 0.0227, val cost: 0.0284, train acc: 0.9905, val acc: 0.9884, dice train: 0.9115, dice val: 0.8931, iou train: 0.8373, iou val: 0.8068
# epoch: 20, train cost: 0.0228, val cost: 0.0271, train acc: 0.9905, val acc: 0.9887, dice train: 0.9162, dice val: 0.8955, iou train: 0.8453, iou val: 0.8108
# Tiempo total de ejecución: 00:07:46

# %% [markdown]
# ### Graficas métricas

# %%
def plot_results(results, y_key, ylabel, title):
    plt.figure(figsize=(10, 5), dpi=300)
    for n in range(len(results)):
        plt.plot(results[n]["History"]["epoch"], results[n]["History"][y_key], 
                 linestyle='-', label=results[n]["Batch_size"])

    plt.xlabel('Época')
    plt.ylabel(ylabel)
    plt.xticks(results[0]["History"]["epoch"])
    plt.title(title)

    plt.grid(True, linestyle='-', linewidth=0.7, alpha=0.7)
    plt.legend()
    plt.tight_layout()
    plt.show()

# Llamadas a la función para cada gráfico
plot_results(results, "val_cost", 'Pérdida', 'Relación entre el tamaño de lote y la pérdida en el conjunto de validación')
plot_results(results, "val_iou", 'IoU', 'Relación entre el tamaño de lote y el IoU en el conjunto de validación')
